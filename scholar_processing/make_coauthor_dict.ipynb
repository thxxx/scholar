# %%
import pandas as pd

df1 = pd.read_csv("../files/output (1).csv")
df2 = pd.read_csv("../files/output_backup.csv")
df3 = pd.read_csv("../files/output_onlydog.csv")
merged = pd.concat([df1, df2, df3])
print(len(merged))

merged['author_id'] = merged['author_id'].apply(lambda x: x.split('/citations?user=')[1] if '/citations?user=' in x else x)

merged = merged.drop_duplicates(subset=['title', 'author_id'], keep='first')
print(len(merged))
# Out:
# 555798
# 217248

# %%
import pandas as pd
from collections import defaultdict
import json

coauthors = defaultdict(set)

# Step 1: group by title
for title, group in merged.groupby("title"):
    authors = group["author_id"].tolist()
    
    # 단독 저자라도 키를 먼저 만들어준다
    for a in authors:
        coauthors[a]  # touch key
    
    # Step 2: add coauthors
    n = len(authors)
    for i in range(n):
        for j in range(i + 1, n):
            a, b = authors[i], authors[j]
            coauthors[a].add(b)
            coauthors[b].add(a)

# Step 3: convert sets to lists
coauthors = {k: sorted(list(v)) for k, v in coauthors.items()}

with open("coauthors.json", "w") as f:
    json.dump(coauthors, f)

# %% [markdown]
# ### Get One Scholar Profile

# %%
import requests
import pandas as pd
import json
import argparse
from tqdm import tqdm

api_key = ""
url = "https://api.scrapingdog.com/google_scholar/author"

df = pd.read_csv("scholar_from_google_deep_learning_korean.csv")
author_ids = df['author_id'].tolist()

detail_profiles = []
extracted_authors = []

for aidx, author_id in tqdm(enumerate(author_ids[5:8])):
    params = {
        "api_key": api_key,
        "author_id": author_id,
        "page": 0,
        "sort": "pubdate"
    }

    response = requests.get(url, params=params)

    if response.status_code != 200:
        print(f"[author {author_id}] Request failed with status code: {response.status_code}")
        continue

    data = response.json()
    first_data = data  # co_authors, cited_by, author 정보는 첫 페이지 기준으로 사용
    all_articles = data.get("articles", []).copy()

    if len(data.get("articles", [])) == 20:
        for page in range(20, 41, 20):
            params = {
                "api_key": api_key,
                "author_id": author_id,
                "page": page,
                "sort": "pubdate"
            }

            response = requests.get(url, params=params)
            if response.status_code != 200:
                print(f"[author {author_id}] (page {page}) Request failed with status code: {response.status_code}")
                break

            page_data = response.json()
            page_articles = page_data.get("articles", [])

            if not page_articles:
                break

            all_articles.extend(page_articles)

            if len(page_articles) < 20:
                break

    author = first_data["author"]

    input_data = {
        "author_id": author_id,  # 원래 코드에 "author_id" 문자열이 들어가 있던 부분 수정
        "name": author.get("name"),
        "affiliations": author.get("affiliations"),
        "email": author.get("email"),
        "interests": [a["title"] for a in author.get("interests", [])],
        "image_thumbnail": author.get("thumbnail"),
        "articles": [
            {
                "title": d.get("title"),
                "citation_id": d.get("citation_id"),
                "publication": d.get("publication"),
                "citation_count": d.get("cited_by", {}).get("value"),
                "year": int(d["year"]) if d.get("year") not in (None, "") else None,
            }
            for d in all_articles if d.get("title") != ""
        ],
        "total_citation_count": first_data["cited_by"]["table"][0]["citations"]["all"],
        "since_2020_citation_count": first_data["cited_by"]["table"][0]["citations"]["since_2020"],
        "h_index": first_data["cited_by"]["table"][1]["h_index"]["all"],
    }
    detail_profiles.append(input_data)

    # co_authors도 첫 페이지 기준으로만 읽음
    co_authors = first_data.get("co_authors", [])
    if co_authors:
        for co_author in co_authors:
            author_input_data = {
                "author_id": co_author.get("author_id"),
                "author_names": co_author.get("name"),
                "affiliations": co_author.get("affiliations"),
            }
            extracted_authors.append(author_input_data)
    print(input_data)
# Out:
# 1it [00:06,  6.96s/it]
# {'author_id': 'Tj996iwAAAAJ', 'name': 'Moon Il Kim', 'affiliations': 'Gachon University', 'email': 'Verified email at gachon.ac.kr', 'interests': ['Nanobiotechnology', 'Biosensor', 'Nanozyme'], 'image_thumbnail': 'https://scholar.google.comhttps://scholar.googleusercontent.com/citations?view_op=view_photo&user=Tj996iwAAAAJ&citpid=1', 'articles': [{'title': 'A colorimetric strategy for quantifying amino acids using E. coli auxotrophs displaying gold-binding proteins', 'citation_id': 'Tj996iwAAAAJ:t7zJ5fGR-2UC', 'publication': 'Biosensors and Bioelectronics, 118182, 2025', 'citation_count': '', 'year': 2025}, {'title': 'Hybrid nanoflower-incorporated foldable paper biosensor for colorimetric detection of sodium benzoate based on inhibition of D-amino acid oxidase', 'citation_id': 'Tj996iwAAAAJ:z_wVstp3MssC', 'publication': 'Microchemical Journal, 115979, 2025', 'citation_count': '', 'year': 2025}, {'title': 'Bridging the barrier: insights into blood biomarkers and therapeutic strategies targeting choroid plexus and BBB dysfunction in alzheimer’s disease', 'citation_id': 'Tj996iwAAAAJ:VLnqNzywnoUC', 'publication': 'Biomarker research 13 (1), 116, 2025', 'citation_count': '1', 'year': 2025}, {'title': '현장검사를 위한 등온핵산증폭 연구의 최근 동향', 'citation_id': 'Tj996iwAAAAJ:XD-gHx7UXLsC', 'publication': 'KSBB Journal 40 (3), 185-201, 2025', 'citation_count': '', 'year': 2025}, {'title': 'Quinoline based dual fluorescence chemosensor for the detection of Zn2+ and Cd2+ ions', 'citation_id': 'Tj996iwAAAAJ:uJ-U7cs_P_0C', 'publication': 'Journal of Materials Science: Materials in Electronics 36 (27), 1761, 2025', 'citation_count': '', 'year': 2025}, {'title': 'Breaking the Selectivity Barrier of Single‐Atom Nanozymes Through Out‐of‐Plane Ligand Coordination', 'citation_id': 'Tj996iwAAAAJ:2KloaMYe4IUC', 'publication': 'Advanced Materials 37 (38), 2506480, 2025', 'citation_count': '2', 'year': 2025}, {'title': 'Peroxidase-laccase dual enzymatic activities of bovine serum albumin-copper hybrid nanoflowers for detecting ascorbic acid and degrading phenolic dyes', 'citation_id': 'Tj996iwAAAAJ:35r97b3x0nAC', 'publication': 'International Journal of Biological Macromolecules, 146912, 2025', 'citation_count': '1', 'year': 2025}, {'title': 'Dual-Mode Optical Detection of Sulfide Ions Using Copper-Anchored Nitrogen-Doped Graphene Quantum Dot Nanozymes', 'citation_id': 'Tj996iwAAAAJ:evX43VCCuoAC', 'publication': 'Biosensors 15 (8), 528, 2025', 'citation_count': '', 'year': 2025}, {'title': 'Unveiling blood biomarkers for neuronal hyperplasticity: Insights from AD molecular subtyping, a comprehensive review', 'citation_id': 'Tj996iwAAAAJ:j8SEvjWlNXcC', 'publication': "Alzheimer's & Dementia 21 (7), e70475, 2025", 'citation_count': '', 'year': 2025}, {'title': 'Graphitic Carbon Nitride-Based Dual-mode Aptasensor for Highly Sensitive Detection of Salmonella Typhimurium', 'citation_id': 'Tj996iwAAAAJ:ZfRJV9d4-WMC', 'publication': '한국생물공학회 학술대회, 256-256, 2025', 'citation_count': '', 'year': 2025}, {'title': 'Signal-off colorimetric and signal-on fluorometric dual-mode aptasensor for ultrasensitive detection of Salmonella Typhimurium using graphitic carbon nitride', 'citation_id': 'Tj996iwAAAAJ:ZuybSZzF8UAC', 'publication': 'Food Chemistry 465, 142176, 2025', 'citation_count': '14', 'year': 2025}, {'title': 'Enhanced vitamin B12 detection using a CxNixOyFeyOx+ 3 bimetal-organic framework: A comprehensive electrochemical study', 'citation_id': 'Tj996iwAAAAJ:JQOojiI6XY0C', 'publication': 'Electrochimica Acta 512, 145476, 2025', 'citation_count': '1', 'year': 2025}, {'title': 'Large-sized and highly crystalline ceria nanorods with abundant Ce 3+ species achieve efficient intracellular ROS scavenging', 'citation_id': 'Tj996iwAAAAJ:7T2F9Uy0os0C', 'publication': 'Nanoscale Horizons 10 (4), 791-802, 2025', 'citation_count': '2', 'year': 2025}, {'title': 'Synthesis and in vitro study of biocompatible polysuccinimide as an amoxicillin carrier for pH-responsiveness', 'citation_ ...
# 2it [00:12,  6.21s/it]
# {'author_id': 'tYy-bzgAAAAJ', 'name': 'Qiao Jin, MD', 'affiliations': 'National Institutes of Health', 'email': 'Verified email at nih.gov - Homepage', 'interests': ['Information Retrieval', 'Language Modeling', 'Biomedical Informatics', 'Medical AI'], 'image_thumbnail': 'https://scholar.google.comhttps://scholar.googleusercontent.com/citations?view_op=view_photo&user=tYy-bzgAAAAJ&citpid=10', 'articles': [{'title': 'AgentMD: Empowering language agents for risk prediction with large-scale clinical tool learning', 'citation_id': 'tYy-bzgAAAAJ:j3f4tGmQtD8C', 'publication': 'Nature Communications, 2025', 'citation_count': '32', 'year': 2025}, {'title': 'Adversarial prompt and fine-tuning attacks threaten medical large language models', 'citation_id': 'tYy-bzgAAAAJ:evX43VCCuoAC', 'publication': 'Nature Communications, 2025', 'citation_count': '13*', 'year': 2025}, {'title': 'A foundation model for human-ai collaboration in medical literature mining', 'citation_id': 'tYy-bzgAAAAJ:2KloaMYe4IUC', 'publication': 'Nature Communications, 2025', 'citation_count': '6', 'year': 2025}, {'title': 'Risks of AI scientists: prioritizing safeguarding over autonomy', 'citation_id': 'tYy-bzgAAAAJ:tzM49s52ZIMC', 'publication': 'Nature Communications, 2025', 'citation_count': '90*', 'year': 2025}, {'title': 'Gene-R1: Reasoning with Data-Augmented Lightweight LLMs for Gene Set Analysis', 'citation_id': 'tYy-bzgAAAAJ:uJ-U7cs_P_0C', 'publication': 'arXiv preprint arXiv:2509.10575, 2025', 'citation_count': '', 'year': 2025}, {'title': 'Accelerating clinical evidence synthesis with large language models', 'citation_id': 'tYy-bzgAAAAJ:lSLTfruPkqcC', 'publication': 'npj Digital Medicine (Nature Portfolio), 2025', 'citation_count': '17', 'year': 2025}, {'title': 'GeneAgent: self-verification language agent for gene-set analysis using domain databases', 'citation_id': 'tYy-bzgAAAAJ:kzcrU_BdoSEC', 'publication': 'Nature Methods, 2025', 'citation_count': '39', 'year': 2025}, {'title': 'MedCite: Can Language Models Generate Verifiable Text for Medicine?', 'citation_id': 'tYy-bzgAAAAJ:W5xh706n7nkC', 'publication': 'ACL Findings, 2025', 'citation_count': '3', 'year': 2025}, {'title': 'Knowledge-guided Contextual Gene Set Analysis Using Large Language Models', 'citation_id': 'tYy-bzgAAAAJ:j8SEvjWlNXcC', 'publication': 'arXiv preprint arXiv:2506.04303, 2025', 'citation_count': '', 'year': 2025}, {'title': 'Cell-o1: Training LLMs to Solve Single-Cell Reasoning Puzzles with Reinforcement Learning', 'citation_id': 'tYy-bzgAAAAJ:JQOojiI6XY0C', 'publication': 'arXiv preprint arXiv:2506.02911, 2025', 'citation_count': '5', 'year': 2025}, {'title': 'TrialPanorama: Database and Benchmark for Systematic Review and Design of Clinical Trials', 'citation_id': 'tYy-bzgAAAAJ:UHK10RUVsp4C', 'publication': 'arXiv preprint arXiv:2505.16097, 2025', 'citation_count': '1', 'year': 2025}, {'title': 'Benchmarking retrieval-augmented generation for chemistry', 'citation_id': 'tYy-bzgAAAAJ:8AbLer7MMksC', 'publication': 'COLM, 2025', 'citation_count': '11', 'year': 2025}, {'title': 'Leveraging long context in retrieval augmented language models for medical question answering', 'citation_id': 'tYy-bzgAAAAJ:geHnlv5EZngC', 'publication': 'npj Digital Medicine (Nature Portfolio), 2025', 'citation_count': '19*', 'year': 2025}, {'title': 'Recommending Clinical Trials for Online Patient Cases using Artificial Intelligence', 'citation_id': 'tYy-bzgAAAAJ:sSrBHYA8nusC', 'publication': 'arXiv preprint arXiv:2504.20059, 2025', 'citation_count': '', 'year': 2025}, {'title': 'Benchmarking large language models for biomedical natural language processing applications and recommendations', 'citation_id': 'tYy-bzgAAAAJ:P5F9QuxV20EC', 'publication': 'Nature Communications, 2025', 'citation_count': '163*', 'year': 2025}, {'title': 'Preliminary analysis of the impact of lab results on large language model generated differential diagnoses', 'citation_id': 'tYy-bzgAAAAJ:CHSYGLWDkRkC', 'publication': 'npj Digital  ...
# 3it [00:20,  6.69s/it]
# {'author_id': 'JI12R3IAAAAJ', 'name': 'Eun-Song Lee', 'affiliations': 'Yonsei University College of Dentistry', 'email': 'Verified email at yuhs.ac', 'interests': ['Dentistry'], 'image_thumbnail': 'https://scholar.google.comhttps://scholar.googleusercontent.com/citations?view_op=view_photo&user=JI12R3IAAAAJ&citpid=3', 'articles': [{'title': 'Diagnostic accuracy of quantitative light-induced fluorescence in detecting caries of various types and locations: a systematic review and meta-analysis', 'citation_id': 'JI12R3IAAAAJ:g5m5HwL7SMYC', 'publication': 'Scientific Reports 15 (1), 39905, 2025', 'citation_count': '', 'year': 2025}, {'title': 'Biofluorescence imaging as a valid alternative for dental calculus detection Biofluorescence imaging as a valid alternative for dental calculus detection', 'citation_id': 'JI12R3IAAAAJ:2P1L_qKh6hAC', 'publication': 'Photodiagnosis and Photodynamic Therapy, 104738, 2025', 'citation_count': '', 'year': 2025}, {'title': 'Impact of denture use on masticatory performance and nutritional status among older adults', 'citation_id': 'JI12R3IAAAAJ:pqnbT2bcN3wC', 'publication': 'Journal of Korean Academy of Oral Health 49 (2), 81-88, 2025', 'citation_count': '', 'year': 2025}, {'title': 'Efficient gingival health screening using biofluorescence of anterior dental biofilms', 'citation_id': 'JI12R3IAAAAJ:70eg2SAEIzsC', 'publication': 'Photodiagnosis and Photodynamic Therapy 53, 104546, 2025', 'citation_count': '2', 'year': 2025}, {'title': 'Caries prevention effects of nano silver fluoride sustained release orthodontic elastomerics in dental microcosm biofilms', 'citation_id': 'JI12R3IAAAAJ:vV6vV6tmYwMC', 'publication': 'Journal of Dentistry 156, 105649, 2025', 'citation_count': '1', 'year': 2025}, {'title': 'Red biofluorescence revealed by dental bleaching in discolored pits and fissures of occlusal caries', 'citation_id': 'JI12R3IAAAAJ:lSLTfruPkqcC', 'publication': 'Journal of Dentistry 156, 105646, 2025', 'citation_count': '1', 'year': 2025}, {'title': 'Development of a novel tongue biofilm index using bacterial biofluorescence', 'citation_id': 'JI12R3IAAAAJ:O3NaXMp0MMsC', 'publication': 'Scientific Reports 14 (1), 30196, 2024', 'citation_count': '1', 'year': 2024}, {'title': 'Generational shift for clinical application of the QLF system for evaluating tooth wear', 'citation_id': 'JI12R3IAAAAJ:JV2RwH3_ST0C', 'publication': 'Photodiagnosis and Photodynamic Therapy 50, 104413, 2024', 'citation_count': '', 'year': 2024}, {'title': 'Quantitative assessment of early caries lesion activity using novel dye-enhanced fluorescence imaging', 'citation_id': 'JI12R3IAAAAJ:M3NEmzRMIkIC', 'publication': 'Journal of Dentistry 150, 105352, 2024', 'citation_count': '1', 'year': 2024}, {'title': 'A novel toothbrush with a thin-head, slender-neck and super-tapered bristles enhancing accessibility in hard-to-reach areas: a crossover randomized trial', 'citation_id': 'JI12R3IAAAAJ:blknAaTinKkC', 'publication': 'BMC oral health 24 (1), 1186, 2024', 'citation_count': '3', 'year': 2024}, {'title': 'Drug delivery and antibiofilm efficacy of nano silver fluoride sustained release orthodontic elastomerics against Streptococcus mutans', 'citation_id': 'JI12R3IAAAAJ:maZDTaKrznsC', 'publication': 'Scientific Reports 14 (1), 19912, 2024', 'citation_count': '5', 'year': 2024}, {'title': "Implications of Japan's 8020 Campaign and the Current Status of Oral Health in the Elderly of Korea and Japan", 'citation_id': 'JI12R3IAAAAJ:hMod-77fHWUC', 'publication': '대한치과의사협회지 62 (8), 517-527, 2024', 'citation_count': '', 'year': 2024}, {'title': 'Distinguishing discolored caries lesions using biofluorescence and dental bleaching: An in vitro simulation model study', 'citation_id': 'JI12R3IAAAAJ:k_IJM867U9cC', 'publication': 'Photodiagnosis and Photodynamic Therapy 48, 104262, 2024', 'citation_count': '2', 'year': 2024}, {'title': 'Detection of pit and fissure sealant microleakage using quantitative light-induced fluorescence technology: an in  ...
